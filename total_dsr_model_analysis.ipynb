# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler
from scipy import stats
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Had to change constraint for DSR_total to [0,4]

# %%
## Full by round data
real_df = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/scaled_round_sg_2018.csv')

nodsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_plyr_nodsr.csv')
nodsr_c_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_course_nodsr.csv')
nodsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_obj_nodsr.csv')

dsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_plyr_.csv')
dsr_c_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_csg_sg_.csv')
dsr_cd_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_c_sg_.csv')
dsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_obj_.csv')

# %%
tot_nodsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_total_plyr_nodsr.csv')
tot_nodsr_c_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_total_course_nodsr.csv')
tot_nodsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_total_obj_nodsr.csv')

tot_dsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_total_2018_plyr_.csv')
tot_dsr_c_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_total_2018_csg_sg_.csv')
tot_dsr_cd_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_total_2018_c_sg_.csv')
tot_dsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_total_2018_obj_.csv')

# %%
dsr_p_ests['AGG_sg_total'] = dsr_p_ests['sg_drive'] + dsr_p_ests['sg_appr'] + dsr_p_ests['sg_short'] + dsr_p_ests['sg_putt']
dsr_p_ests['EST_sg_total'] = tot_dsr_p_ests['sg_total']

dsr_c_ests['AGG_sg_total'] = dsr_c_ests['sg_drive'] + dsr_c_ests['sg_appr'] + dsr_c_ests['sg_short'] + dsr_c_ests['sg_putt']
dsr_c_ests['EST_sg_total'] = tot_dsr_c_ests['sg_total']

dsr_cd_ests['AGG_dsr_total'] = dsr_cd_ests['dsr_drive'] + dsr_cd_ests['dsr_appr'] + dsr_cd_ests['dsr_short'] + dsr_cd_ests['dsr_putt']
dsr_cd_ests['EST_dsr_total'] = tot_dsr_cd_ests['dsr_total']

# %%
print(dsr_c_ests.sort_values(by = 'AGG_sg_total', ascending = False))
# Out:
#     c_idx                     course_name  sg_drive   sg_appr  sg_short   sg_putt  AGG_sg_total  EST_sg_total
# 29     14         PGA National (Champion)  0.563445  2.007043 -0.258874  0.095922      2.407537      2.368528
# 10     15                 Pebble Beach GL  0.329059  1.018262 -0.061904  0.405587      1.691005      1.662663
# 8      11  Innisbrook Resort (Copperhead)  0.765939  0.985939 -0.246223  0.104455      1.610110      1.604936
# 36     29                    TPC Sawgrass  0.364995  0.447254  0.276359  0.170907      1.259515      1.340945
# 2      32                   TPC Summerlin -0.056885  0.684188  0.521169 -0.002710      1.145762      1.159051
# 12     19                      Riviera CC  0.456899  0.324737  0.005913  0.335060      1.122609      1.083939
# 0       1           Bay Hill Club & Lodge  0.485794  0.588924  0.004746  0.037210      1.116674      1.208840
# ...

# %%
## EST ARE Z SCORES
print(dsr_p_ests[dsr_p_ests['num_rounds'] >10].sort_values(by = 'AGG_sg_total', ascending = False))
# Out:
#      p_idx                player  sg_drive   sg_appr  sg_short   sg_putt  num_rounds  AGG_sg_total  EST_sg_total
# 161    161        Dustin Johnson  2.140566  1.744466  0.577066  1.017509        58.0      5.479606      2.110130
# 267    267           Justin Rose  1.487055  1.264827  1.457145  0.653434        49.0      4.862461      2.025725
# 385    385          Rory McIlroy  1.821309  0.729755  1.102480  0.769851        49.0      4.423394      1.526734
# 219    219             Jason Day  0.808957  0.237493  1.562500  1.782819        47.0      4.391769      1.412953
# 268    268         Justin Thomas  1.183617  1.916049  0.623026  0.479622        64.0      4.202314      1.800944
# 74      74     Bryson DeChambeau  1.486162  1.319331  0.509792  0.834620        74.0      4.149905      1.636643
# 457    457           Tiger Woods  0.421507  1.921546  1.148286  0.448797        57.0      3.940136      1.649526
# ...

# %%
## Made AGG z scores
## should be able to go back and forth

dsr_p_ests['AGG_sg_total'] = stats.zscore(dsr_p_ests['AGG_sg_total'])
print(dsr_p_ests[dsr_p_ests['num_rounds'] >10].sort_values(by = 'AGG_sg_total', ascending = False))
# Out:
#      p_idx                player  sg_drive   sg_appr  sg_short   sg_putt  num_rounds  AGG_sg_total  EST_sg_total
# 161    161        Dustin Johnson  2.140566  1.744466  0.577066  1.017509        58.0      1.730717      2.110130
# 267    267           Justin Rose  1.487055  1.264827  1.457145  0.653434        49.0      1.599172      2.025725
# 385    385          Rory McIlroy  1.821309  0.729755  1.102480  0.769851        49.0      1.505584      1.526734
# 219    219             Jason Day  0.808957  0.237493  1.562500  1.782819        47.0      1.498843      1.412953
# 268    268         Justin Thomas  1.183617  1.916049  0.623026  0.479622        64.0      1.458460      1.800944
# 74      74     Bryson DeChambeau  1.486162  1.319331  0.509792  0.834620        74.0      1.447289      1.636643
# 457    457           Tiger Woods  0.421507  1.921546  1.148286  0.448797        57.0      1.402577      1.649526
# ...

# %%
print(dsr_cd_ests.sort_values(by = 'AGG_dsr_total', ascending = False))
# Out:
#     c_idx                     course_name  dsr_drive  dsr_appr  dsr_short  dsr_putt  AGG_dsr_total  EST_dsr_total
# 11     17               Quail Hollow Club   0.603452  0.442528   0.465076  0.844499       2.355556       1.471290
# 30     18                    Ridgewood CC   0.573611  0.633144   0.148693  0.999983       2.355431       1.354334
# 20     30                  TPC Scottsdale   0.668806  0.708821   0.135771  0.745877       2.259274       1.639850
# 9      12           Keene Trace Golf Club   0.569626  0.999999   0.228448  0.404728       2.202801       1.706927
# 19     28     TPC San Antonio - AT&T Oaks   0.720464  0.531993   0.465666  0.468073       2.186195       1.630686
# 36     29                    TPC Sawgrass   0.552316  0.515672   0.489452  0.565716       2.123156       1.549903
# 28     13            Muirfield Village GC   0.450086  0.999998   0.555308  0.101922       2.107314       1.433116
# ...
