# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler
from scipy import stats
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
## Full by hole data
hole_df = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/sg_hole_2018_data.csv')

nodsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_byhole_plyr_nodsr.csv')
nodsr_h_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_byhole_hole_nodsr.csv')
nodsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_byhole_obj_nodsr.csv')

dsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_byhole_2018_plyr_.csv')
dsr_h_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_byhole_2018_hsg_sg_.csv')
dsr_hd_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_byhole_2018_h_sg_.csv')
dsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_byhole_2018_obj_.csv')

# %%
## Full by round data
round_df = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/scaled_round_sg_2018.csv')

r_nodsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_plyr_nodsr.csv')
r_nodsr_c_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_course_nodsr.csv')
r_nodsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_obj_nodsr.csv')

r_dsr_p_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_plyr_.csv')
r_dsr_c_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_csg_sg_.csv')
r_dsr_cd_ests = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_c_sg_.csv')
r_dsr_obj = pd.read_csv('C:/Users/Luke/OneDrive/Research/sg_data/realv2_2018_obj_.csv')

# %%
test = nodsr_h_ests['course_hole'].str.replace(r"\(.*\)","").split(',')[0]
test

# %%
print(dsr_p_ests[dsr_p_ests['num_rounds']>10].sort_values(by = 'sg_short', ascending = False))
# Out:
#      p_idx                player  sg_drive   sg_appr  sg_short   sg_putt  num_rounds
# 247    247              John Oda -0.170111 -1.178593  2.215412 -0.189226        15.0
# 332    332       Morgan Hoffmann -0.671374 -0.988473  1.723633 -1.539897        13.0
# 1        1        Aaron Baddeley -0.718073 -0.150132  1.681483 -0.106355        66.0
# 11      11            Alex Cejka  0.012899 -0.133777  1.626256 -0.244832        60.0
# 346    346           Omar Uresti -1.930652 -2.599463  1.609666 -3.709038        17.0
# 297    297      Louis Oosthuizen  1.120186  0.213057  1.600884  0.541456        42.0
# 219    219             Jason Day  0.808957  0.237493  1.562500  1.782819        47.0
# 267    267           Justin Rose  1.487055  1.264827  1.457145  0.653434        49.0
# 351    351          Patrick Reed  0.476465  0.397794  1.372839  0.668434        59.0
# 482    482          Webb Simpson -0.108278  0.974003  1.324755  1.407334        77.0
# ...

# %%
print(dsr_cd_ests.sort_values(by = 'dsr_drive', ascending = False))
# Out:
#     c_idx                     course_name  dsr_drive  dsr_appr  dsr_short  dsr_putt
# 34      4        Club de Golf Chapultepec   0.829002  0.294283   0.281497  0.254946
# 35     16    Plantation Course at Kapalua   0.779782  0.053457   0.083870  0.999921
# 19     28     TPC San Antonio - AT&T Oaks   0.720464  0.531993   0.465666  0.468073
# 0       1           Bay Hill Club & Lodge   0.686288  0.471509   0.324751  0.563409
# 33     33               The Old White TPC   0.670221  0.435121   0.186440  0.302754
# 20     30                  TPC Scottsdale   0.668806  0.708821   0.135771  0.745877
# 11     17               Quail Hollow Club   0.603452  0.442528   0.465076  0.844499
# 17     26      TPC Potomac at Avenel Farm   0.588041  0.477181   0.349098  0.209243
# 5       8                   GC of Houston   0.586486  0.400553   0.157280  0.393725
# 24      0                    Aronimink GC   0.584707  0.438534   0.157132  0.239830
# ...

# %%
#plt.scatter(dsr_c_ests['sg_drive'], dsr_cd_ests['dsr_drive'])
